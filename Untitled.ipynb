# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, AutoMinorLocator

import numpy as np
import seaborn as sns
import pandas as pd
import os

# %%
def func(t,params):
    p = params
    ret = p[0]*np.exp(-(t-p[2])/p[4])/(1.+np.exp(-(t-p[2])/p[3])) + p[1]
    return ret
    print np.exp((t-p[2])/p[4])

# %%
A  = 16.
B  = 0.
t0 = 50.
trise = 10.
tfall = 50.

vals = [A,B,t0,trise,tfall]

# %%
t = np.arange(0,100,1.)

# %%
print vals
# Out:
# [16.0, 0.0, 50.0, 10.0, 50.0]

# %%
#PLOT FOR PAPER:  Histogram of Depth by field
f, ax = plt.subplots(1, figsize=(10,10))
mpl.style.use('ggplot')

ax.plot(t,func(t,vals),color="blue",linestyle='solid')

plt.show()
